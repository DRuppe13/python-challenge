# %%
# Import the pathlib and csv library
from pathlib import Path
import csv

# Set the file path
csvpath = Path('budget_data.csv')

# Initialize variable to hold salaries
profit_loss_list = []

# Initialize line_num variable
line_num = 0

# Open the input path as a file object
with open(csvpath, 'r') as csvfile:



    # Pass in the csv file to the csv.reader() function
    # (with ',' as the delmiter/separator) and return the csvreader object
    csvreader = csv.reader(csvfile, delimiter=',')
    # Print the datatype of the csvreader
    print(type(csvfile))

    # Go to the next row from the start of the file
    # (which is often the first row/header) and iterate line_num by 1
    header = next(csvreader)
    line_num += 1
    # Print the header
    print(f"{header} <---- HEADER")

    # Read each row of data after the header
    for row in csvreader:
        # Print the row
        print(row)
        # Set Profit/Loss variable equal to the value in the 2nd column of each row
        profit_loss = int(row[1])
        # Append the row salary value to the list of salaries
        profit_loss_list.append(profit_loss)
        
print(profit_loss_list)
# Out:
# <class '_io.TextIOWrapper'>
# ['Date', 'Profit/Losses'] <---- HEADER
# ['Jan-2010', '867884']
# ['Feb-2010', '984655']
# ['Mar-2010', '322013']
# ['Apr-2010', '-69417']
# ['May-2010', '310503']
# ['Jun-2010', '522857']
# ['Jul-2010', '1033096']
# ['Aug-2010', '604885']
# ['Sep-2010', '-216386']
# ['Oct-2010', '477532']
# ['Nov-2010', '893810']
# ['Dec-2010', '-80353']
# ['Jan-2011', '779806']
# ['Feb-2011', '-335203']
# ['Mar-2011', '697845']
# ['Apr-2011', '793163']
# ['May-2011', '485070']
# ['Jun-2011', '584122']
# ['Jul-2011', '62729']
# ['Aug-2011', '668179']
# ['Sep-2011', '899906']
# ['Oct-2011', '834719']
# ['Nov-2011', '132003']
# ['Dec-2011', '309978']
# ['Jan-2012', '-755566']
# ['Feb-2012', '1170593']
# ['Mar-2012', '252788']
# ['Apr-2012', '1151518']
# ['May-2012', '817256']
# ['Jun-2012', '570757']
# ['Jul-2012', '506702']
# ['Aug-2012', '-1022534']
# ['Sep-2012', '475062']
# ['Oct-2012', '779976']
# ['Nov-2012', '144175']
# ['Dec-2012', '542494']
# ...

# %%
# track revenue parameters 
total_months = 0
prev_revenue = 0
month_of_change = []
pro_lo = []
greatest_increase = ["", 0]
greatest_decrease = ["", 9999999999999999999]
total_p_l = 0

# %%
for p_l in profit_loss_list:
    # sum the total months
    total_months += 1

# %%
total_months
# Out:
# 86

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13132\3830396704.py in <module>
#       1 #The total net amount of "Profit/Loss" over entire period
# ----> 2 prot_lo = pro_lo + int(row["profit_loss"])
#       3
#       4 #Track change in revenue
#       5 pro_lo = int(row["profit_loss_list"]) - prev_revenue
#
# TypeError: list indices must be integers or slices, not str

# %%
#the total net amount of 'Profit/Loss' over the entire period
sum_profit = 0
sum_loss = 0
totalpl = 0
profit = 0 

for p_L in profit_loss_list:
    profit = int(row[1])
    if profit > 0:
            sum_profit = sum_profit + profit
    elif profit < 0:
        sum_loss = sum_loss - profit
totalpl = sum_profit - sum_loss

print(f"total:{p_l}")
# Out:
# total:671099

# %%
print

# %%
# Initialize variable to hold Profit/Loss
budget = [0]

# Initialize line_num variable
line_num = 0

# create a Pandas dataframe from a csv file
budget_data_df = pd.read_csv(file_path)

# %%
# Open the input path as file object
with open(file_path, 'r') as budget_data_df:
    # Pass in the csv file to the csv.reader() function
    # (with ',' as the delmiter/separator) and return the csvreader object
    budget_data_df = csv.reader(budget_data_df, delimiter=',')
    # Print the datatype of the csvreader
    print(type(file_path))

    # Go to the next row from the start of the file
    # (which is often the first row/header) and iterate line_num by 1
    header = next(budget_data_df)
    line_num += 0
    # Print the header
    print(f"{header} <---- HEADER")

    # Read each row of data after the header
    for row in budget_data_df:
        # Print the row
        print(row)
        # Set Profit/Loss variable equal to the value in the 2nd column of each row
        profit_loss = int(row[1])
        # Append the row date value to the list of profit/loss
        budget.append(profit_loss)
        
        total_months = 
for total_months in budget:
    # Calculate total months
    total_months += 1
    
    print(f"Greatest Increase in Profits: {(change[change == change.max()])(great_increase = change.max())}
print(f"Greatest Decrease in Profits: {change[change == change.min()][greatest_decrease = change.min()]
